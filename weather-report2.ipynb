# %%
import pandas as pd

# %%
data=pd.read_csv(r"C:\\Excel Files\\local_weather.csv",index_col="DATE")

# %%
data
# Out:
#                 STATION                                  NAME  ACMH  ACSH  \
# DATE
# 1960-01-01  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 1960-01-02  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 1960-01-03  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 1960-01-04  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 1960-01-05  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# ...                 ...                                   ...   ...   ...
# 2022-01-24  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 2022-01-25  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 2022-01-26  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 2022-01-27  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 2022-01-28  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
#
# ...

# %%
data.isnull().sum()
# Out:
# STATION        0
# NAME           0
# ACMH       11015
# ACSH       11015
# AWND        8808
# DAPR       16851
# FMTM       14669
# FRGT       16857
# MDPR       16851
# PGTM        8347
# PRCP         281
# SNOW        5479
# SNWD        5355
# TAVG       14822
# TMAX           9
# TMIN          10
# TSUN       15708
# WDF1       11015
# WDF2        8807
# WDF5        8894
# WDFG       12592
# WSF1       11015
# WSF2        8806
# WSF5        8894
# WSFG       12592
# WT01       13149
# WT02       16526
# WT03       16740
# WT04       16855
# WT05       16831
# WT07       16857
# WT08       13662
# WT09       16857
# WT16       14904
# WT18       16856
# dtype: int64

# %%
core_data=data[["PRCP","TMAX","TMIN"]].copy()

# %%
core_data
# Out:
#             PRCP  TMAX  TMIN
# DATE
# 1960-01-01   0.0  49.0  30.0
# 1960-01-02   0.0  49.0  29.0
# 1960-01-03   0.0  54.0  35.0
# 1960-01-04   0.0  54.0  36.0
# 1960-01-05   0.0  55.0  33.0
# ...          ...   ...   ...
# 2022-01-24   0.0  60.0  39.0
# 2022-01-25   0.0  57.0  43.0
# 2022-01-26   0.0  57.0  41.0
# 2022-01-27   0.0  67.0  39.0
# 2022-01-28   0.0  64.0  39.0
#
# [16859 rows x 3 columns]

# %%
core_data.isnull().sum()/ core_data.shape[0]
# Out:
# PRCP    0.016668
# TMAX    0.000534
# TMIN    0.000593
# dtype: float64

# %%
core_data=core_data.fillna(0)

# %%
core_data.isnull().sum()
# Out:
# PRCP    0
# TMAX    0
# TMIN    0
# dtype: int64

# %%
from sklearn.linear_model import Ridge

# %%
reg = Ridge(alpha=0.1)

# %%
test=core_data[:"2021-12-31"]

# %%
train=core_data["2021-12-31":]

# %%
core_data
# Out:
#             PRCP  TMAX  TMIN
# DATE
# 1960-01-01   0.0  49.0  30.0
# 1960-01-02   0.0  49.0  29.0
# 1960-01-03   0.0  54.0  35.0
# 1960-01-04   0.0  54.0  36.0
# 1960-01-05   0.0  55.0  33.0
# ...          ...   ...   ...
# 2022-01-24   0.0  60.0  39.0
# 2022-01-25   0.0  57.0  43.0
# 2022-01-26   0.0  57.0  41.0
# 2022-01-27   0.0  67.0  39.0
# 2022-01-28   0.0  64.0  39.0
#
# [16859 rows x 3 columns]

# %%
core_data["Target"] = core_data.shift(-1)["TMAX"]

# %%
core_data
# Out:
#             PRCP  TMAX  TMIN  Target
# DATE
# 1960-01-01   0.0  49.0  30.0    49.0
# 1960-01-02   0.0  49.0  29.0    54.0
# 1960-01-03   0.0  54.0  35.0    54.0
# 1960-01-04   0.0  54.0  36.0    55.0
# 1960-01-05   0.0  55.0  33.0    53.0
# ...          ...   ...   ...     ...
# 2022-01-24   0.0  60.0  39.0    57.0
# 2022-01-25   0.0  57.0  43.0    57.0
# 2022-01-26   0.0  57.0  41.0    67.0
# 2022-01-27   0.0  67.0  39.0    64.0
# 2022-01-28   0.0  64.0  39.0     NaN
#
# [16859 rows x 4 columns]

# %%
core_data=core_data.iloc[:-1,:].copy()

# %%
core_data
# Out:
#             PRCP  TMAX  TMIN  Target
# DATE
# 1960-01-01   0.0  49.0  30.0    49.0
# 1960-01-02   0.0  49.0  29.0    54.0
# 1960-01-03   0.0  54.0  35.0    54.0
# 1960-01-04   0.0  54.0  36.0    55.0
# 1960-01-05   0.0  55.0  33.0    53.0
# ...          ...   ...   ...     ...
# 2022-01-23   0.0  60.0  41.0    60.0
# 2022-01-24   0.0  60.0  39.0    57.0
# 2022-01-25   0.0  57.0  43.0    57.0
# 2022-01-26   0.0  57.0  41.0    67.0
# 2022-01-27   0.0  67.0  39.0    64.0
#
# [16858 rows x 4 columns]

# %%
train=core_data[:"2021-12-31"]

# %%
test=core_data["2021-12-31":]

# %%
reg.fit(train[["PRCP","TMAX","TMIN"]],train["Target"])
# Out:
# Ridge(alpha=0.1)

# %%
predictions=reg.predict(test[["PRCP","TMAX","TMIN"]])

# %%
from sklearn.metrics import mean_absolute_error

# %%
error=mean_absolute_error(test["Target"],predictions)

# %%
error
# Out:
# 2.764367438452024

# %%
combined =pd.concat([test["Target"],pd.Series(predictions,index=test.index)],axis=1)
combined.columns = ["Actual","Predictions"]

# %%
combined
# Out:
#             Actual  Predictions
# DATE
# 2021-12-31    51.0    54.355897
# 2022-01-01    55.0    52.780401
# 2022-01-02    54.0    55.039934
# 2022-01-03    57.0    55.812750
# 2022-01-04    57.0    59.585067
# 2022-01-05    55.0    59.646391
# 2022-01-06    56.0    58.427478
# 2022-01-07    56.0    58.186698
# 2022-01-08    61.0    57.343162
# 2022-01-09    58.0    60.657881
# 2022-01-10    60.0    59.453534
# 2022-01-11    59.0    60.137571
# 2022-01-12    56.0    59.438969
# 2022-01-13    61.0    58.056330
# 2022-01-14    60.0    60.479589
# 2022-01-15    61.0    60.850738
# 2022-01-16    60.0    61.727632
# 2022-01-17    55.0    60.672446
# 2022-01-18    56.0    56.822852
# 2022-01-19    60.0    57.699746
# 2022-01-20    68.0    59.959279
# 2022-01-21    69.0    65.726388
# 2022-01-22    60.0    66.959865
# 2022-01-23    60.0    60.137571
# 2022-01-24    57.0    59.780987
# 2022-01-25    57.0    58.398348
# 2022-01-26    67.0    58.041765
# 2022-01-27    64.0    64.671202

# %%
combined.plot()
# Out:
# <AxesSubplot:xlabel='DATE'>
